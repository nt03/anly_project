# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('permit_reviews.csv')
# Out:
# C:\Users\tneha\Anaconda\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (37,39,40,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
df.shape
# Out:
# (185372, 54)

# %%
df.dtypes
# Out:
# As_Of_Date                         object
# alias                              object
# permit_cap_status                  object
# pdox_b1_id                         object
# Project_Status                     object
# Project_Description                object
# Project_CreateDate                 object
# ReviewCycle                       float64
# TaskName                           object
# TaskStatus                         object
# GroupName                          object
# elapsed_workdays                  float64
# RC_ReviewStatus                    object
# FlowTask_CreatedDate               object
# FlowTask_DateUpdated               object
# FlowTask_DateAccepted              object
# RC_HowAssigned                     object
# RC_ReviewComments_confidential     object
# Fee_Assessed                      float64
# job_class                          object
# over_30                            object
# AGENCY                             object
# ...

# %%
#missing values

columns = df.columns
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing})

missing_value_df
# Out:
#                                                    column_name  \
# As_Of_Date                                          As_Of_Date
# alias                                                    alias
# permit_cap_status                            permit_cap_status
# pdox_b1_id                                          pdox_b1_id
# Project_Status                                  Project_Status
# Project_Description                        Project_Description
# Project_CreateDate                          Project_CreateDate
# ReviewCycle                                        ReviewCycle
# TaskName                                              TaskName
# TaskStatus                                          TaskStatus
# GroupName                                            GroupName
# elapsed_workdays                              elapsed_workdays
# RC_ReviewStatus                                RC_ReviewStatus
# FlowTask_CreatedDate                      FlowTask_CreatedDate
# ...

# %%
bct = df.groupby("building_construction_type").size()
bct
# Out:
# building_construction_type
# TYPE II - Non-Combustible Construction         17465
# TYPE II-A - Non-Combustible Construction        1020
# TYPE II-B - Non-Combustible Construction        1453
# TYPE III - Non-Combustible Exterior Walls      17685
# TYPE III-A - Non-Combustible Exterior Walls     1431
# TYPE III-B - Non-Combustible Exterior Walls     2263
# TYPE IV - Heavy Timber                          1181
# TYPE V - Any Materials Permitted               25731
# TYPE V-A - Any Materials Permitted              2795
# TYPE V-B - Any Materials Permitted              2380
# Type I - Fire-Resistive Non-Combustible          944
# Type I - Fire-Resistive Non-combustible        26305
# Type I-A - Fire-Resistive Non-Combustible       1880
# Type I-B - Fire-Resistive Non-Combustible       3002
# dtype: int64

# %% [markdown]
# difference between types?

# %%
pt = df.groupby("permit_type").size()

# %%
pt
# Out:
# permit_type
# Construction    154591
# Shop Drawing     30781
# dtype: int64

# %%
ut = df.groupby("use_type").size()
ut
# Out:
# use_type
# C    89218
# R    60675
# dtype: int64

# %%
df.groupby("existing_use_of_building").size()
# Out:
# existing_use_of_building
# Agricultural Building - U                                      69
# Animal Hospital - B                                            26
# Antennas - B                                                 1085
# Apartment Houses - R-2                                      11509
# Appliances - F-1                                               65
# Arena - A-4                                                   121
# Art Gallery - B                                                59
# Artists studio - B                                             20
# Assisted Living Facility - I-1                                176
# Athletic Equipment - F-1                                       14
# Automobiles and other Motor Vehicles - F-1                    129
# Bakery - F-1                                                    8
# Bank - B                                                      459
# Banquet Hall - A-2                                             33
# ...

# %%
df.groupby("proposed_use_of_building").size()
# Out:
# proposed_use_of_building
# Agricultural Building - U                                      27
# Amusement Park - A-5                                           43
# Animal Hospital - B                                            26
# Antennas - B                                                   22
# Apartment Houses - R-2                                      14150
# Appliances - F-1                                               65
# Arena - A-4                                                    94
# Art Gallery - B                                                34
# Artists studio - B                                            142
# Assisted Living Facility - I-1                                146
# Athletic Equipment - F-1                                       43
# Auditorium - A-3                                               24
# Bakery - F-1                                                    8
# Bank - B                                                      419
# ...

# %%
df.groupby("Project_Status").size()
# Out:
# Project_Status
# Applied                             12
# Approved                        156735
# Canceled                            53
# Final Processing                   400
# HFC                              14287
# Pending Payment                   2173
# Pre-Screen Acceptance               23
# Pre-Screen Resubmit Request        129
# Pre-Screen Review                   27
# Under Review                     11455
# dtype: int64

# %%
df.groupby("ReviewCycle").size()
# Out:
# ReviewCycle
# 0.0     39105
# 1.0    101477
# 2.0     27250
# 3.0     10648
# 4.0      3711
# 5.0      1153
# 6.0       430
# 7.0       109
# 8.0        27
# 9.0        10
# dtype: int64

# %%
df.groupby("over_30").size()
# Out:
# over_30
# <30    164525
# >30     20847
# dtype: int64

# %%
df.groupby("job_class").size()
# Out:
# job_class
# A       5023
# AA      4959
# B      12113
# C      43006
# D      16957
# DGS     2904
# E      47546
# M       6065
# R         73
# SD     30738
# TL      3612
# TPR     7843
# V       4002
# dtype: int64

# %%
df.groupby("GroupName").size()
# Out:
# GroupName
# Applicant                       22593
# CFA Review                        558
# Chinatown Review                   44
# DC Water Review                  2488
# DC Water Review Supervisor       1662
# DDOE Review Supervisor             22
# DDOE SE-SW Review                  34
# DDOE WSP Review                     8
# DDOT Review                      1458
# DDOT Review Supervisor            983
# DOEE AQ Review                      2
# DOEE FP Review                    135
# DOEE GAR Review                  1341
# DOEE Review Supervisor           2733
# DOEE SE-SW Review                4408
# DOH Review                        895
# DOH Review Supervisor             461
# EISF Review                        46
# Electrical Review                6049
# Electrical Review Supervisor     4491
# Elevator Review                  1276
# Elevator Review Supervisor        920
# Energy Review                    5266
# Energy Review Supervisor         3359
# ...
